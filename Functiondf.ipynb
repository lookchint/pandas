# %%
import pandas as pd

# %%
def readMDT(path):
    df=pd.read_excel(path,sheet_name=0,usecols='E:V',skiprows=5,skip_footer=44)
    df.drop([0],axis=0,inplace=True)
    return df

# %%
readMDT(path ="AT-33_F_PTW_6.125''.xls")
# Out:
# C:\Users\ZKasiditK\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: the 'skip_footer' keyword is deprecated, use 'skipfooter' instead
#    Schlum_file_nb  Test # TMD_BRT   TVD_RT  TVD_MSL Mud_type  \
# 1              23    1.01  1938.7  1805.57  1776.57      SDF
# 2              26    1.02    2004  1866.34  1837.34      SDF
# 3              28    1.03  2124.9  1978.77  1949.77      SDF
# 4              29    1.04  2140.8   1993.7   1964.7      SDF
# 5              30    1.05  2163.1  2014.65  1985.65      SDF
# 6              32    1.06  2207.5  2056.32  2027.32      SDF
# 7              34    1.07    2266  2111.07  2082.07      SDF
# 8              35    1.08  2288.8  2132.32  2103.32      SDF
# 9              37    1.09    2344  2183.66  2154.66      SDF
# 10             38    1.10  2360.7  2199.17  2170.17      SDF
# 11             40    1.11    2426  2260.09  2231.09      SDF
# ...
